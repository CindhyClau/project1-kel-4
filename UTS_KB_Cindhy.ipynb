# %% [markdown]
# <a href="https://colab.research.google.com/github/CindhyClau/project1-kel-4/blob/main/UTS_KB_Cindhy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import pandas dan masukan file yang sudah di download

# %%
import pandas as pd

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-7553e47b-a997-49c6-8cc2-ee890e0813c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7553e47b-a997-49c6-8cc2-ee890e0813c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Untuk membaca file dan menampilkan file

# %%
df = pd.read_csv('my_file (1) (1).csv')
df
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %% [markdown]
# Untuk menampilkan ringkasan informasi tentang data

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              20 non-null     int64
#  1   Peak                              9 non-null      object
#  2   All Time Peak                     6 non-null      object
#  3   Actual gross                      20 non-null     object
#  4   Adjusted gross (in 2022 dollars)  20 non-null     object
#  5   Artist                            20 non-null     object
#  6   Tour title                        20 non-null     object
#  7   Year(s)                           20 non-null     object
#  8   Shows                             20 non-null     int64
#  9   Average gross                     20 non-null     object
#  10  Ref.                              20 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 1.8+ KB
# None

# %%
df
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %% [markdown]
# Untuk mencari duplikat dan untuk menghapus duplikat

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %% [markdown]
# Untuk mengidentifikasi dan mengisi nilai yang hilang (NaN)pada kolom Peak menjadi Unknown

# %%
df.isnull().sum()
df['Peak']=df['Peak'].astype(str)
df['Peak']=df['Peak'].replace('NaN','Unknown')
df
# Out:
#     Rank     Peak All Time Peak     Actual gross  \
# 0      1        1             2     $780,000,000
# 1      2        1          7[2]     $579,800,000
# 2      3     1[4]          2[5]     $411,000,000
# 3      4     2[7]         10[7]     $397,300,000
# 4      5     2[4]           NaN     $345,675,146
# 5      6     2[4]         10[9]     $305,158,363
# 6      7    2[10]           NaN     $280,000,000
# 7      7  Unknown           NaN     $257,600,000
# 8      9  Unknown           NaN     $256,084,556
# 9     10  Unknown           NaN     $250,400,000
# 10    11  Unknown           NaN  $229,100,000[b]
# 11    12  Unknown        14[17]     $227,400,000
# 12    13  Unknown           NaN     $204,000,000
# 13    14    1[20]           NaN     $200,000,000
# 14    15     2[c]           NaN     $194,000,000
# 15    16  Unknown           NaN     $184,000,000
# 16    17  Unknown           NaN     $170,000,000
# 17    18  Unknown           NaN     $169,800,000
# ...

# %% [markdown]
# Untuk mengidentifikasi dan mengisi nilai yang hilang (NaN)pada kolom All Time Peak menjadi Unknown

# %%
df.isnull().sum()
df['All Time Peak']=df['Peak'].astype(str)
df['All Time Peak']=df['Peak'].replace('NaN','Unknown')
df
# Out:
#     Rank     Peak All Time Peak     Actual gross  \
# 0      1        1             1     $780,000,000
# 1      2        1             1     $579,800,000
# 2      3     1[4]          1[4]     $411,000,000
# 3      4     2[7]          2[7]     $397,300,000
# 4      5     2[4]          2[4]     $345,675,146
# 5      6     2[4]          2[4]     $305,158,363
# 6      7    2[10]         2[10]     $280,000,000
# 7      7  Unknown       Unknown     $257,600,000
# 8      9  Unknown       Unknown     $256,084,556
# 9     10  Unknown       Unknown     $250,400,000
# 10    11  Unknown       Unknown  $229,100,000[b]
# 11    12  Unknown       Unknown     $227,400,000
# 12    13  Unknown       Unknown     $204,000,000
# 13    14    1[20]         1[20]     $200,000,000
# 14    15     2[c]          2[c]     $194,000,000
# 15    16  Unknown       Unknown     $184,000,000
# 16    17  Unknown       Unknown     $170,000,000
# 17    18  Unknown       Unknown     $169,800,000
# ...

# %% [markdown]
# Untuk membersikan data pada kolom Peak dengan menghapus angka yang di apit oleh tanda kurung siku([])

# %%
df['Peak'] = df['Peak'].str.replace(r'\[\d+\]', '', regex=True).astype(str)
df
# Out:
#     Rank     Peak All Time Peak     Actual gross  \
# 0      1        1             1     $780,000,000
# 1      2        1             1     $579,800,000
# 2      3        1          1[4]     $411,000,000
# 3      4        2          2[7]     $397,300,000
# 4      5        2          2[4]     $345,675,146
# 5      6        2          2[4]     $305,158,363
# 6      7        2         2[10]     $280,000,000
# 7      7  Unknown       Unknown     $257,600,000
# 8      9  Unknown       Unknown     $256,084,556
# 9     10  Unknown       Unknown     $250,400,000
# 10    11  Unknown       Unknown  $229,100,000[b]
# 11    12  Unknown       Unknown     $227,400,000
# 12    13  Unknown       Unknown     $204,000,000
# 13    14        1         1[20]     $200,000,000
# 14    15     2[c]          2[c]     $194,000,000
# 15    16  Unknown       Unknown     $184,000,000
# 16    17  Unknown       Unknown     $170,000,000
# 17    18  Unknown       Unknown     $169,800,000
# ...

# %% [markdown]
# Untuk membersikan data pada kolom All Time Peak dengan menghapus angka yang di apit oleh tanda kurung siku([])

# %%
df['All Time Peak'] = df['All Time Peak'].str.replace(r'\[\d+\]', '', regex=True).astype(str)
df
# Out:
#     Rank     Peak All Time Peak     Actual gross  \
# 0      1        1             1     $780,000,000
# 1      2        1             1     $579,800,000
# 2      3        1             1     $411,000,000
# 3      4        2             2     $397,300,000
# 4      5        2             2     $345,675,146
# 5      6        2             2     $305,158,363
# 6      7        2             2     $280,000,000
# 7      7  Unknown       Unknown     $257,600,000
# 8      9  Unknown       Unknown     $256,084,556
# 9     10  Unknown       Unknown     $250,400,000
# 10    11  Unknown       Unknown  $229,100,000[b]
# 11    12  Unknown       Unknown     $227,400,000
# 12    13  Unknown       Unknown     $204,000,000
# 13    14        1             1     $200,000,000
# 14    15     2[c]             2     $194,000,000
# 15    16  Unknown       Unknown     $184,000,000
# 16    17  Unknown       Unknown     $170,000,000
# 17    18  Unknown       Unknown     $169,800,000
# ...

# %% [markdown]
# Untuk membersikan data pada kolom Tour Title dengan menghapus simbol simbol yang ada di belakang judul

# %%
df['Tour title'] = df['Tour title'].str.replace(r'\s‡\[\d+\]\[\w+\]', '', regex=True)
df
# Out:
#     Rank     Peak All Time Peak     Actual gross  \
# 0      1        1             1     $780,000,000
# 1      2        1             1     $579,800,000
# 2      3        1             1     $411,000,000
# 3      4        2             2     $397,300,000
# 4      5        2             2     $345,675,146
# 5      6        2             2     $305,158,363
# 6      7        2             2     $280,000,000
# 7      7  Unknown       Unknown     $257,600,000
# 8      9  Unknown       Unknown     $256,084,556
# 9     10  Unknown       Unknown     $250,400,000
# 10    11  Unknown       Unknown  $229,100,000[b]
# 11    12  Unknown       Unknown     $227,400,000
# 12    13  Unknown       Unknown     $204,000,000
# 13    14        1             1     $200,000,000
# 14    15     2[c]             2     $194,000,000
# 15    16  Unknown       Unknown     $184,000,000
# 16    17  Unknown       Unknown     $170,000,000
# 17    18  Unknown       Unknown     $169,800,000
# ...

# %%
df['Tour title'] = df['Tour title'].str.replace(r'†', '', regex=True).str.lower()
df
# Out:
#     Rank     Peak All Time Peak     Actual gross  \
# 0      1        1             1     $780,000,000
# 1      2        1             1     $579,800,000
# 2      3        1             1     $411,000,000
# 3      4        2             2     $397,300,000
# 4      5        2             2     $345,675,146
# 5      6        2             2     $305,158,363
# 6      7        2             2     $280,000,000
# 7      7  Unknown       Unknown     $257,600,000
# 8      9  Unknown       Unknown     $256,084,556
# 9     10  Unknown       Unknown     $250,400,000
# 10    11  Unknown       Unknown  $229,100,000[b]
# 11    12  Unknown       Unknown     $227,400,000
# 12    13  Unknown       Unknown     $204,000,000
# 13    14        1             1     $200,000,000
# 14    15     2[c]             2     $194,000,000
# 15    16  Unknown       Unknown     $184,000,000
# 16    17  Unknown       Unknown     $170,000,000
# 17    18  Unknown       Unknown     $169,800,000
# ...

# %%
df['Tour title'] = df['Tour title'].str.replace(r'\[\w+\]', '', regex=True)
df
# Out:
#     Rank     Peak All Time Peak     Actual gross  \
# 0      1        1             1     $780,000,000
# 1      2        1             1     $579,800,000
# 2      3        1             1     $411,000,000
# 3      4        2             2     $397,300,000
# 4      5        2             2     $345,675,146
# 5      6        2             2     $305,158,363
# 6      7        2             2     $280,000,000
# 7      7  Unknown       Unknown     $257,600,000
# 8      9  Unknown       Unknown     $256,084,556
# 9     10  Unknown       Unknown     $250,400,000
# 10    11  Unknown       Unknown  $229,100,000[b]
# 11    12  Unknown       Unknown     $227,400,000
# 12    13  Unknown       Unknown     $204,000,000
# 13    14        1             1     $200,000,000
# 14    15     2[c]             2     $194,000,000
# 15    16  Unknown       Unknown     $184,000,000
# 16    17  Unknown       Unknown     $170,000,000
# 17    18  Unknown       Unknown     $169,800,000
# ...
